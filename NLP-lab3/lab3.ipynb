# %%
import nltk
from nltk.corpus import gutenberg
from nltk.tokenize import word_tokenize
from collections import Counter

# %% [markdown]
# First task

# %%
def wagner_fischer(word1, word2):
    len_1 = len(word1)
    len_2 = len(word2)

    dist = [[0] * (len_2 + 1) for _ in range(len_1 + 1)]

    for i in range(len_1 + 1):
        dist[i][0] = i
    for j in range(len_2 + 1):
        dist[0][j] = j

    for i in range(1, len_1 + 1):
        for j in range(1, len_2 + 1):
            if word1[i - 1] == word2[j - 1]:
                cost = 0
            else:
                cost = 1
            dist[i][j] = min(dist[i - 1][j] + 1,      
                             dist[i][j - 1] + 1,      
                             dist[i - 1][j - 1] + cost)  

    return dist[len_1][len_2]

word1 = "magic"
word2 = "people"
print(f"Length between '{word1}' and '{word2}' is {wagner_fischer(word1, word2)}")
# Out:
# Length between 'magic' and 'people' is 6

# %%
def qwerty_distance(char1, char2):
    qwerty_keyboard = {
        'q': {'w', 'a', 's'},
        'w': {'q', 'a', 's', 'd', 'e'},
        'e': {'w', 's', 'd', 'f', 'r'},
        'r': {'e', 'd', 'f', 'g', 't'},
        't': {'r', 'f', 'g', 'h', 'y'},
        'y': {'t', 'g', 'h', 'j', 'u'},
        'u': {'y', 'h', 'j', 'k', 'i'},
        'i': {'u', 'j', 'k', 'l', 'o'},
        'o': {'i', 'k', 'l', 'p'},
        'p': {'o', 'l'},

        'a': {'q', 'w', 's', 'z'},
        's': {'q', 'w', 'e', 'a', 'd', 'z', 'x'},
        'd': {'w', 'e', 'r', 's', 'f', 'x', 'c'},
        'f': {'e', 'r', 't', 'd', 'g', 'c', 'v'},
        'g': {'r', 't', 'y', 'f', 'h', 'v', 'b'},
        'h': {'t', 'y', 'u', 'g', 'j', 'b', 'n'},
        'j': {'y', 'u', 'i', 'h', 'k', 'n', 'm'},
        'k': {'u', 'i', 'o', 'j', 'l', 'm'},
        'l': {'i', 'o', 'p', 'k'},

        'z': {'a', 's', 'x'},
        'x': {'z', 's', 'd', 'c'},
        'c': {'x', 'd', 'f', 'v'},
        'v': {'c', 'f', 'g', 'b'},
        'b': {'v', 'g', 'h', 'n'},
        'n': {'b', 'h', 'j', 'm'},
        'm': {'n', 'j', 'k'}
    }
    
    if char1 in qwerty_keyboard and char2 in qwerty_keyboard[char1]:
        return 1 
    else:
        return float('inf') 

def modified_wagner_fischer(word1, word2):
    len_1 = len(word1)
    len_2 = len(word2)

    dist = [[0] * (len_2 + 1) for _ in range(len_1 + 1)]

    for i in range(len_1 + 1):
        dist[i][0] = i
    for j in range(len_2 + 1):
        dist[0][j] = j

    for i in range(1, len_1 + 1):
        for j in range(1, len_2 + 1):
            if word1[i - 1] == word2[j - 1]:
                cost = 0
            else:
                cost = qwerty_distance(word1[i - 1], word2[j - 1])
            dist[i][j] = min(dist[i - 1][j] + 1,      
                             dist[i][j - 1] + 1,     
                             dist[i - 1][j - 1] + cost)  

    return dist[len_1][len_2]

word1 = "magic"
word2 = "people"
print(f"Length between '{word1}' and '{word2}' is {modified_wagner_fischer(word1, word2)}")
# Out:
# Length between 'magic' and 'people' is 10

# %%
def damerau_levenshtein_distance(char1, char2):
    if char1 == char2:
        return 0
    else:
        return 1

def qwerty_distance(char1, char2):
    qwerty_keyboard = {
        'q': {'w', 'a', 's'},
        'w': {'q', 'a', 's', 'd', 'e'},
        'e': {'w', 's', 'd', 'f', 'r'},
        'r': {'e', 'd', 'f', 'g', 't'},
        't': {'r', 'f', 'g', 'h', 'y'},
        'y': {'t', 'g', 'h', 'j', 'u'},
        'u': {'y', 'h', 'j', 'k', 'i'},
        'i': {'u', 'j', 'k', 'l', 'o'},
        'o': {'i', 'k', 'l', 'p'},
        'p': {'o', 'l'},

        'a': {'q', 'w', 's', 'z'},
        's': {'q', 'w', 'e', 'a', 'd', 'z', 'x'},
        'd': {'w', 'e', 'r', 's', 'f', 'x', 'c'},
        'f': {'e', 'r', 't', 'd', 'g', 'c', 'v'},
        'g': {'r', 't', 'y', 'f', 'h', 'v', 'b'},
        'h': {'t', 'y', 'u', 'g', 'j', 'b', 'n'},
        'j': {'y', 'u', 'i', 'h', 'k', 'n', 'm'},
        'k': {'u', 'i', 'o', 'j', 'l', 'm'},
        'l': {'i', 'o', 'p', 'k'},

        'z': {'a', 's', 'x'},
        'x': {'z', 's', 'd', 'c'},
        'c': {'x', 'd', 'f', 'v'},
        'v': {'c', 'f', 'g', 'b'},
        'b': {'v', 'g', 'h', 'n'},
        'n': {'b', 'h', 'j', 'm'},
        'm': {'n', 'j', 'k'}
    }
    
    if char1 in qwerty_keyboard and char2 in qwerty_keyboard[char1]:
        return 1  
    else:
        return float('inf')  

def modified_wagner_fischer(word1, word2):
    len_1 = len(word1)
    len_2 = len(word2)

    dist = [[0] * (len_2 + 1) for _ in range(len_1 + 1)]

    for i in range(len_1 + 1):
        dist[i][0] = i
    for j in range(len_2 + 1):
        dist[0][j] = j

    for i in range(1, len_1 + 1):
        for j in range(1, len_2 + 1):
            if word1[i - 1] == word2[j - 1]:
                cost = 0
            else:
                cost = qwerty_distance(word1[i - 1], word2[j - 1])

            # Транспонування
            if i > 1 and j > 1 and word1[i - 1] == word2[j - 2] and word1[i - 2] == word2[j - 1]:
                transposition_cost = dist[i - 2][j - 2] + cost
                dist[i][j] = min(dist[i][j], transposition_cost)

            dist[i][j] = min(dist[i][j], dist[i - 1][j] + 1,     
                             dist[i][j - 1] + 1,                 
                             dist[i - 1][j - 1] + cost)         

    return dist[len_1][len_2]

word1 = "magic"
word2 = "people"
print("Length between '{}' and '{}' is {}".format(word1, word2, modified_wagner_fischer(word1, word2)))
# Out:
# Length between 'magic' and 'people' is 0

# %% [markdown]
# Second task

# %%
nltk.download('gutenberg')
text = gutenberg.raw('melville-moby_dick.txt')
words = word_tokenize(text)

bag_of_words = Counter(words)

print("Bag-of-Words:")
print(bag_of_words)
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# Bag-of-Words:
# Counter({',': 19204, 'the': 13715, '.': 7306, 'of': 6513, 'and': 6010, 'a': 4545, 'to': 4515, ';': 4173, 'in': 3908, 'that': 2978, 'his': 2459, 'it': 2196, 'I': 2113, '!': 1767, 'is': 1722, '--': 1713, 'with': 1659, 'he': 1658, 'was': 1639, 'as': 1620, "''": 1615, "'s": 1585, '``': 1456, 'all': 1444, 'for': 1413, 'this': 1280, 'at': 1230, 'not': 1170, 'by': 1135, 'but': 1110, 'him': 1058, 'from': 1052, 'be': 1027, '?': 1004, 'on': 1003, 'so': 914, 'one': 880, 'you': 841, 'whale': 782, 'had': 767, 'have': 763, 'there': 710, 'But': 703, 'or': 697, 'were': 679, 'now': 645, 'which': 640, 'me': 624, 'their': 612, 'The': 609, 'are': 586, 'they': 586, 'an': 582, 'some': 578, 'then': 570, 'my': 564, 'like': 558, 'when': 553, 'upon': 537, 'into': 519, 'out': 518, 'more': 500, 'up': 499, 'Ahab': 498, 'no': 483, 'man': 472, 'them': 471, 'ship': 454, 'what': 438, 'old': 429, 'ye': 427, 'would': 425, 'if': 421, 'been': 415, 'we': 411, 'other': 409, 'over': 397, 'these': 381, 'will': 377, 'its': 372, 'And': 367, 'sea': 365, 'do': 363, 'only': 360, 'down': 355, 'such': 336, 'though': 335, 'her': 329, 'any': 320, 'who': 318, 'time': 316, 'very': 311, 'It': 309, 'than': 309, 'long': 305, 'about': 304, 'said': 302, 'still': 299, 'yet': 299, 'those': 297, 'before': 293, 'has': 291, 'great': 290, 'must': 283, 'seemed': 283, 'boat': 281, 'most': 276, 'two': 275, 'last': 275, 'here': 270, "'": 270, 'head': 270, 'Whale': 270, 'did': 264, 'way': 262, 'can': 256, 'again': 252, 'Queequeg': 252, 'Stubb': 252, 'see': 250, "n't": 250, 'after': 247, 'little': 247, 'your': 240, 'round': 240, 'whales': 236, 'In': 236, 'say': 235, 'thou': 231, 'men': 231, 'three': 231, 'may': 229, 'us': 228, 'He': 227, 'through': 226, 'every': 222, 'could': 221, 'being': 219, 'much': 218, 'while': 216, '(': 215, ')': 215, 'Captain': 213, 'off': 210, 'first': 210, 'same': 210, 'own': 205, 'himself': 203, 'our': 198, 'For': 197, ':': 196, 'never': 195, 'hand': 194, 'Starbuck': 193, 'ever': 190, 'side': 189, 'thing': 188, 'where': 188, 'how': 187, 'almost': 186, 'might': 183, 'too': 182, 'go': 180, 'should': 180, 'even': 179, 'good': 178, 'made': 177, 'away': 172, 'world': 166, 'well': 166, 'water': 166, 'Pequod': 164, 'What': 163, 'many': 161, 'seen': 160, 'deck': 159, 'among': 158, 'white': 158, 'day': 157, 'eyes': 155, 'far': 155, 'cried': 155, 'without': 154, 'A': 153, 'sort': 152, 'come': 150, 'CHAPTER': 150, 'know': 149, 'thought': 148, 'part': 148, 'back': 146, 'So': 145, 'There': 144, 'once': 144, 'sir': 143, 'boats': 142, 'Now': 139, 'crew': 139, 'air': 138, 'whole': 136, 'life': 135, 'look': 134, 'Sperm': 133, 'against': 132, 'things': 132, 'came': 130, 'night': 130, 'thee': 129, 'God': 129, 'each': 127, 'feet': 125, 'hands': 122, 'small': 121, 'As': 120, 'till': 120, 'something': 119, 'take': 118, 'let': 118, 'tell': 118, 'both': 118, 'Oh': 117, 'between': 117, 'found': 115, 'under': 115, 'called': 113, 'soon': 113, 'full': 111, 'saw': 111, 'place': 111, 'times': 111, 'body': 110, 'just': 110, 'along': 110, 'think': 109, 'make': 109, 'captain': 109, 'heard': 109, 'line': 108, 'towards': 107, 'thus': 107, 'This': 106, 'another': 106, "'ll": 106, 'moment': 105, 'thy': 105, 'poor': 104, 'sight': 104, 'Flask': 104, 'fish': 103, 'she': 103, 'nothing': 102, 'sperm': 102, 'whaling': 99, 'THE': 98, 'went': 97, 'No': 96, 'strange': 95, 'end': 95, 'face': 94, 'high': 93, 'few': 92, 'get': 92, 'voyage': 91, 'does': 91, 'sun': 91, 'dead': 90, 'years': 89, 'right': 89, 'half': 89, 'stood': 89, 'White': 89, 'also': 88, 'heart': 87, 'certain': 87, 'whose': 86, 'hold': 86, 'That': 85, 'matter': 85, 'leg': 85, 'am': 84, 'shall': 84, 'seems': 84, 'arm': 84, 'Nantucket': 84, 'itself': 84, 'seem': 84, 'At': 84, 'Jonah': 83, 'Aye': 83, 'Moby': 82, 'Dick': 82, 'eye': 82, 'perhaps': 82, 'soul': 82, 'indeed': 82, 'sometimes': 81, 'known': 80, 'however': 80, 'seas': 80, 'always': 80, 'wild': 80, 'sail': 79, 'going': 79, 'nor': 79, 'black': 79, 'present': 79, 'within': 78, 'length': 78, 'They' ...

# %%
nltk.download('gutenberg')
text = gutenberg.raw('melville-moby_dick.txt')
words = word_tokenize(text)
word_counts = Counter(words)
N = len(word_counts)
print("There are", N, "words in vocabulary")
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# There are 20742 words in vocabulary

# %%
d = gutenberg.raw('melville-moby_dick.txt')
words = d.split()

word_counts = Counter(words)
for word, count in word_counts.items():
    print(f"The word '{word}' occurs {count} times.")
# Out:
# The word '[Moby' occurs 1 times.
# The word 'Dick' occurs 33 times.
# The word 'by' occurs 1093 times.
# The word 'Herman' occurs 1 times.
# The word 'Melville' occurs 1 times.
# The word '1851]' occurs 1 times.
# The word 'ETYMOLOGY.' occurs 1 times.
# The word '(Supplied' occurs 2 times.
# The word 'a' occurs 4472 times.
# The word 'Late' occurs 1 times.
# The word 'Consumptive' occurs 1 times.
# The word 'Usher' occurs 1 times.
# The word 'to' occurs 4439 times.
# The word 'Grammar' occurs 1 times.
# The word 'School)' occurs 1 times.
# The word 'The' occurs 531 times.
# The word 'pale' occurs 12 times.
# The word 'Usher--threadbare' occurs 1 times.
# The word 'in' occurs 3824 times.
# The word 'coat,' occurs 8 times.
# The word 'heart,' occurs 17 times.
# The word 'body,' occurs 19 times.
# The word 'and' occurs 5881 times.
# The word 'brain;' occurs 6 times.
# The word 'I' occurs 1724 times.
# The word 'see' occurs 190 times.
# The word 'him' occurs 554 times.
# The word 'now.' occurs 19 times.
# The word 'He' occurs 187 times.
# The word 'was' occurs 1564 times.
# The word 'ever' occurs 175 times.
# The word 'dusting' occurs 2 times.
# The word 'his' occurs 2415 times.
# The word 'old' occurs 412 times.
# The word 'lexicons' occurs 1 times.
# The word 'grammars,' occurs 1 times.
# The word 'with' occurs 1645 times.
# The word 'queer' occurs 24 times.
# The word 'handkerchief,' occurs 2 times.
# The word 'mockingly' occurs 1 times.
# The word 'embellished' occurs 3 times.
# The word 'all' occurs 1293 times.
# The word 'the' occurs 13604 times.
# The word 'gay' occurs 12 times.
# The word 'flags' occurs 1 times.
# The word 'of' occurs 6475 times.
# The word 'known' occurs 68 times.
# The word 'nations' occurs 10 times.
# The word 'world.' occurs 19 times.
# The word 'loved' occurs 3 times.
# The word 'dust' occurs 6 times.
# The word 'grammars;' occurs 1 times.
# The word 'it' occurs 1506 times.
# The word 'somehow' occurs 30 times.
# The word 'mildly' occurs 9 times.
# The word 'reminded' occurs 4 times.
# The word 'mortality.' occurs 1 times.
# The word '"While' occurs 2 times.
# The word 'you' occurs 734 times.
# The word 'take' occurs 116 times.
# The word 'hand' occurs 108 times.
# The word 'school' occurs 5 times.
# The word 'others,' occurs 9 times.
# The word 'teach' occurs 4 times.
# The word 'them' occurs 273 times.
# The word 'what' occurs 380 times.
# The word 'name' occurs 46 times.
# The word 'whale-fish' occurs 1 times.
# The word 'is' occurs 1560 times.
# The word 'be' occurs 973 times.
# The word 'called' occurs 102 times.
# The word 'our' occurs 197 times.
# The word 'tongue' occurs 7 times.
# The word 'leaving' occurs 36 times.
# The word 'out,' occurs 37 times.
# The word 'through' occurs 209 times.
# The word 'ignorance,' occurs 2 times.
# The word 'letter' occurs 7 times.
# The word 'H,' occurs 1 times.
# The word 'which' occurs 550 times.
# The word 'almost' occurs 179 times.
# The word 'alone' occurs 24 times.
# The word 'maketh' occurs 5 times.
# The word 'signification' occurs 1 times.
# The word 'word,' occurs 17 times.
# The word 'deliver' occurs 3 times.
# The word 'that' occurs 2680 times.
# The word 'not' occurs 1023 times.
# The word 'true."' occurs 1 times.
# The word '--HACKLUYT' occurs 1 times.
# The word '"WHALE.' occurs 2 times.
# The word '...' occurs 11 times.
# The word 'Sw.' occurs 1 times.
# The word 'Dan.' occurs 2 times.
# The word 'HVAL.' occurs 1 times.
# The word 'This' occurs 96 times.
# The word 'animal' occurs 11 times.
# The word 'named' occurs 8 times.
# The word 'from' occurs 1049 times.
# The word 'roundness' occurs 1 times.
# The word 'or' occurs 686 times.
# The word 'rolling;' occurs 1 times.
# The word 'for' occurs 1357 times.
# The word 'HVALT' occurs 1 times.
# The word 'arched' occurs 6 times.
# The word 'vaulted."' occurs 1 times.
# The word '--WEBSTER'S' occurs 1 times.
# The word 'DICTIONARY' occurs 2 times.
# The word 'It' occurs 258 times.
# The word 'more' occurs 427 times.
# The word 'immediately' occurs 13 times.
# The word 'Dut.' occurs 1 times.
# The word 'Ger.' occurs 1 times.
# The word 'WALLEN;' occurs 1 times.
# The word 'A.S.' occurs 1 times.
# The word 'WALW-IAN,' occurs 1 times.
# The word 'roll,' occurs 3 times.
# The word 'wallow."' occurs 1 times.
# The word '--RICHARDSON'S' occurs 1 times.
# The word 'KETOS,' occurs 1 times.
# The word 'GREEK.' occurs 1 times.
# The word 'CETUS,' occurs 1 times.
# The word 'LATIN.' occurs 1 times.
# The word 'WHOEL,' occurs 1 times.
# The word 'ANGLO-SAXON.' occurs 1 times.
# The word 'HVALT,' occurs 1 times.
# The word 'DANISH.' occurs 1 times.
# The word 'WAL,' occurs 1 times.
# The word 'DUTCH.' occurs 1 times.
# The word 'HWAL,' occurs 1 times.
# The word 'SWEDISH.' occurs 1 times.
# The word 'WHALE,' occurs 4 times.
# The word 'ICELANDIC.' occurs 1 times.
# The word 'ENGLISH.' occurs 1 times.
# The word 'BALEINE,' occurs 1 times.
# The word 'FRENCH.' occurs 1 times.
# The word 'BALLENA,' occurs 1 times.
# The word 'SPANISH.' occurs 1 times.
# The word 'PEKEE-NUEE-NUEE,' occurs 2 times.
# The word 'FEGEE.' occurs 1 times.
# The word 'ERROMANGOAN.' occurs 1 times.
# The word 'EXTRACTS' occurs 1 times.
# The word 'Sub-Sub-Librarian).' occurs 1 times.
# The word 'will' occurs 341 times.
# The word 'seen' occurs 119 times.
# The word 'this' occurs 1131 times.
# The word 'mere' occurs 41 times.
# The word 'painstaking' occurs 1 times.
# The word 'burrower' occurs 1 times.
# The word 'grub-worm' occurs 1 times.
# The word 'poor' occurs 94 times.
# The word 'devil' occurs 30 times.
# The word 'Sub-Sub' occurs 1 times.
# The word 'appears' occurs 5 times.
# The word 'have' occurs 748 times.
# The word 'gone' occurs 40 times.
# The word 'long' occurs 250 times.
# The word 'Vaticans' occurs 1 times.
# The word 'street-stalls' occurs 1 times.
# The word 'earth,' occurs 19 times.
# The word 'picking' occurs 4 times.
# The word 'up' occurs 413 times.
# The word 'whatever' occurs 41 times.
# The word 'random' occurs 5 times.
# The word 'allusions' occurs 7 times.
# The word 'whales' occurs 133 times.
# The word 'he' occurs 1492 times.
# The word 'could' occurs 207 times.
# The word 'anyways' occurs 2 times.
# The word 'find' occurs 53 times.
# The word 'any' occurs 307 times.
# The word 'book' occurs 21 times.
# The word 'whatsoever,' occurs 2 times.
# The word 'sacred' occurs 7 times.
# The word 'profane.' occurs 1 times.
# The word 'Therefore' occurs 4 times.
# The word 'must' occurs 269 times.
# The word 'not,' occurs 26 times.
# The word 'every' occurs 218 times.
# The word 'case' occurs 49 times.
# The word 'at' occurs 1211 times.
# The word 'least,' occurs 15 times.
# The word 'higgledy-piggledy' occurs 1 times.
# The word 'whale' occurs 392 times.
# The word 'statements,' occurs 2 times.
# The word 'however' occurs 52 times.
# The word 'authentic,' occurs 1 times.
# The word 'these' occurs 358 times.
# The word 'extracts,' occurs 1 times.
# The word 'veritable' occurs 4 times.
# The word 'gospel' occurs 1 times.
# The word 'cetology.' occurs 2 times.
# The word 'Far' occurs 4 times.
# The word 'it.' occurs 171 times.
# The word 'As' occurs 114 times.
# The word 'touching' occurs 44 times.
# The word 'ancient' occurs 27 times.
# The word 'authors' occurs 2 times.
# The word 'generally,' occurs 2 times.
# The word 'as' occurs 1590 times.
# The word 'well' occurs 126 times.
# The word 'poets' occurs 3 times.
# The word 'here' occurs 137 times.
# The word 'appearing,' occurs 1 times.
# The word 'extracts' occurs 3 times.
# The word 'are' occurs 565 times.
# The word 'solely' occurs 6 times.
# The word 'valuable' occurs 9 times.
# The word 'entertaining,' occurs 1 times.
# The word 'affording' occurs 2 times.
# The word 'glancing' occurs 11 times.
# The word 'bird's' occurs 3 times.
# The word 'eye' occurs 45 times.
# The word 'view' occurs 26 times.
# The word 'has' occurs 280 times.
# The word 'been' occurs 401 times.
# The word 'promiscuously' occurs 1 times.
# The word 'said,' occurs 33 times.
# The word 'thought,' occurs 14 times.
# The word 'fancied,' occurs 2 times.
# The word 'sung' occurs 2 times.
# The word 'Leviathan,' occurs 14 times.
# The word 'many' occurs 157 times.
# The word 'generations,' occurs 3 times.
# The word 'including' occurs 8 times.
# The word 'own.' occurs 11 times.
# The word 'So' occurs 93 times.
# The word 'fare' occurs 9 times.
# The word 'thee' occurs 45 times.
# The word 'well,' occurs 19 times.
# The word 'Sub-Sub,' occurs 1 times.
# The word 'whose' occurs 85 times.
# The word 'commentator' occurs 1 times.
# The word 'am.' occurs 1 times.
# The word 'Thou' occurs 22 times.
# The word 'belongest' occurs 1 times.
# The word 'hopeless,' occurs 2 times.
# The word 'sallow' occurs 1 times.
# The word 'tribe' occurs 3 times.
# The word 'no' occurs 439 times.
# The word 'wine' occurs 6 times.
# The word 'world' occurs 75 times.
# The word 'warm;' occurs 1 times.
# The word 'whom' occurs 40 times.
# The word 'even' occurs 169 times.
# The word 'Pale' occurs 1 times.
# The word 'Sherry' occurs 1 times.
# The word 'would' occurs 406 times.
# The word 'too' occurs 92 times.
# The word 'rosy-strong;' occurs 1 times.
# The word 'but' occurs 1030 times.
# The word 'one' occurs 750 times.
# The word 'sometimes' occurs 76 times.
# The word 'loves' occurs 1 times.
# The word 'sit,' occurs 2 times.
# The word 'feel' occurs 54 times.
# The word 'poor-devilish,' occurs 1 times.
# The word 'too;' occurs 8 times.
# The word 'grow' occurs 21 times.
# The word 'convivial' occurs 3 times.
# The word 'upon' occurs 531 times.
# The word 'tears;' occurs 1 times.
# The word 'say' occurs 89 times.
# The word 'bluntly,' occurs 1 times.
# The word 'full' occurs 106 times.
# The word 'eyes' occurs 99 times.
# The word 'empty' occurs 19 times.
# The word 'glasses,' occurs 2 times.
# The word 'altogether' occurs 25 times.
# The word 'unpleasant' occurs 3 times.
# The word 'sadness--Give' occurs 1 times.
# The word 'up,' occurs 46 times.
# The word 'Sub-Subs!' occurs 1 times.
# The word 'For' occurs 165 times.
# The word 'how' occurs 168 times.
# The word 'much' occurs 200 times.
# The word 'pains' occurs 12 times.
# The word 'ye' occurs 260 times.
# The word 'please' occurs 2 times.
# The word 'world,' occurs 33 times.
# The word 'so' occurs 784 times.
# The word 'shall' occurs 82 times.
# The word 'go' occurs 143 times.
# The word 'thankless!' occurs 1 times.
# The word 'Would' occurs 10 times.
# The word 'clear' occurs 32 times.
# The word 'out' occurs 436 times.
# The word 'Hampton' occurs 1 times.
# The word 'Court' occurs 1 times.
# The word 'Tuileries' occurs 1 times.
# The word 'ye!' occurs 13 times.
# The word 'But' occurs 638 times.
# The word 'gulp' occurs 2 times.
# The word 'down' occurs 298 times.
# The word 'your' occurs 240 times.
# The word 'tears' occurs 5 times.
# The word 'hie' occurs 1 times.
# The word 'aloft' occurs 29 times.
# The word 'royal-mast' occurs 2 times.
# The word 'hearts;' occurs 2 times.
# The word 'friends' occurs 4 times.
# The word 'who' occurs 253 times.
# The word 'before' occurs 251 times.
# The word 'clearing' occurs 3 times.
# The word 'seven-storied' occurs 1 times.
# The word 'heavens,' occurs 2 times.
# The word 'making' occurs 42 times.
# The word 'refugees' occurs 1 times.
# The word 'long-pampered' occurs 1 times.
# The word 'Gabriel,' occurs 5 times.
# The word 'Michael,' occurs 1 times.
# The word 'Raphael,' occurs 1 times.
# The word 'against' occurs 130 times.
# The word 'coming.' occurs 3 times.
# The word 'Here' occurs 27 times.
# The word 'strike' occurs 24 times.
# The word 'splintered' occurs 7 times.
# The word 'hearts' occurs 21 times.
# The word 'together--there,' occurs 1 times.
# The word 'unsplinterable' occurs 1 times.
# The word 'glasses!' occurs 1 times.
# The word 'EXTRACTS.' occurs 1 times.
# The word '"And' occurs 32 times.
# The word 'God' occurs 51 times.
# The word 'created' occurs 5 times.
# The word 'great' occurs 282 times.
# The word 'whales."' occurs 2 times.
# The word '--GENESIS.' occurs 1 times.
# The word '"Leviathan' occurs 1 times.
# The word 'path' occurs 7 times.
# The word 'shine' occurs 3 times.
# The word 'after' occurs 236 times.
# The word 'him;' occurs 88 times.
# The word 'One' occurs 26 times.
# The word 'think' occurs 95 times.
# The word 'deep' occurs 40 times.
# The word 'hoary."' occurs 1 times.
# The word '--JOB.' occurs 1 times.
# The word '"Now' occurs 2 times.
# The word 'Lord' occurs 24 times.
# The word 'had' occurs 751 times.
# The word 'prepared' occurs 12 times.
# The word 'fish' occurs 40 times.
# The word 'swallow' occurs 8 times.
# The word 'Jonah."' occurs 2 times.
# The word '--JONAH.' occurs 1 times.
# The word '"There' occurs 21 times.
# The word 'ships;' occurs 3 times.
# The word 'there' occurs 414 times.
# The word 'Leviathan' occurs 32 times.
# The word 'thou' occurs 208 times.
# The word 'hast' occurs 19 times.
# The word 'made' occurs 155 times.
# The word 'play' occurs 12 times.
# The word 'therein."' occurs 1 times.
# The word '--PSALMS.' occurs 1 times.
# The word '"In' occurs 17 times.
# The word 'day,' occurs 41 times.
# The word 'sore,' occurs 1 times.
# The word 'great,' occurs 7 times.
# The word 'strong' occurs 22 times.
# The word 'sword,' occurs 7 times.
# The word 'punish' occurs 1 times.
# The word 'piercing' occurs 3 times.
# The word 'serpent,' occurs 1 times.
# The word 'crooked' occurs 8 times.
# The word 'serpent;' occurs 1 times.
# The word 'slay' occurs 4 times.
# The word 'dragon' occurs 4 times.
# The word 'sea."' occurs 4 times.
# The word '--ISAIAH' occurs 1 times.
# The word 'thing' occurs 132 times.
# The word 'soever' occurs 1 times.
# The word 'besides' occurs 17 times.
# The word 'cometh' occurs 1 times.
# The word 'within' occurs 58 times.
# The word 'chaos' occurs 3 times.
# The word 'monster's' occurs 6 times.
# The word 'mouth,' occurs 22 times.
# The word 'beast,' occurs 1 times.
# The word 'boat,' occurs 69 times.
# The word 'stone,' occurs 2 times.
# The word 'goes' occurs 51 times.
# The word 'incontinently' occurs 1 times.
# The word 'foul' occurs 10 times.
# The word 'his,' occurs 15 times.
# The word 'perisheth' occurs 1 times.
# The word 'bottomless' occurs 6 times.
# The word 'gulf' occurs 3 times.
# The word 'paunch."' occurs 1 times.
# The word '--HOLLAND'S' occurs 2 times.
# The word 'PLUTARCH'S' occurs 1 times.
# The word 'MORALS.' occurs 1 times.
# The word '"The' occurs 59 times.
# The word 'Indian' occurs 43 times.
# The word 'Sea' occurs 10 times.
# The word 'breedeth' occurs 1 times.
# The word 'most' occurs 274 times.
# The word 'biggest' occurs 2 times.
# The word 'fishes' occurs 2 times.
# The word 'are:' occurs 1 times.
# The word 'among' occurs 158 times.
# The word 'Whales' occurs 15 times.
# The word 'Whirlpooles' occurs 1 times.
# The word 'Balaene,' occurs 1 times.
# The word 'length' occurs 51 times.
# The word 'four' occurs 63 times.
# The word 'acres' occurs 3 times.
# The word 'arpens' occurs 1 times.
# The word 'land."' occurs 1 times.
# The word 'PLINY.' occurs 1 times.
# The word '"Scarcely' occurs 1 times.
# The word 'we' occurs 386 times.
# The word 'proceeded' occurs 5 times.
# The word 'two' occurs 256 times.
# The word 'days' occurs 53 times.
# The word 'on' occurs 905 times.
# The word 'sea,' occurs 104 times.
# The word 'when' occurs 501 times.
# The word 'about' occurs 272 times.
# The word 'sunrise' occurs 8 times.
# The word 'other' occurs 342 times.
# The word 'monsters' occurs 7 times.
# The word 'appeared.' occurs 1 times.
# The word 'Among' occurs 8 times.
# The word 'former,' occurs 1 times.
# The word 'monstrous' occurs 10 times.
# The word 'size.' occurs 1 times.
# The word 'came' occurs 120 times.
# The word 'towards' occurs 107 times.
# The word 'us,' occurs 36 times.
# The word 'open-mouthed,' occurs 1 times.
# The word 'raising' occurs 4 times.
# The word 'waves' occurs 27 times.
# The word 'sides,' occurs 9 times.
# The word 'beating' occurs 9 times.
# The word 'sea' occurs 139 times.
# The word 'into' occurs 516 times.
# The word 'foam."' occurs 1 times.
# The word '--TOOKE'S' occurs 1 times.
# The word 'LUCIAN.' occurs 1 times.
# The word '"THE' occurs 2 times.
# The word 'TRUE' occurs 1 times.
# The word 'HISTORY."' occurs 1 times.
# The word '"He' occurs 20 times.
# The word 'visited' occurs 6 times.
# The word 'country' occurs 13 times.
# The word 'also' occurs 64 times.
# The word 'catching' occurs 7 times.
# The word 'horse-whales,' occurs 1 times.
# The word 'bones' occurs 32 times.
# The word 'very' occurs 307 times.
# The word 'value' occurs 5 times.
# The word 'their' occurs 611 times.
# The word 'teeth,' occurs 17 times.
# The word 'brought' occurs 38 times.
# The word 'some' occurs 569 times.
# The word 'king.' occurs 2 times.
# The word 'best' occurs 52 times.
# The word 'were' occurs 645 times.
# The word 'catched' occurs 1 times.
# The word 'own' occurs 179 times.
# The word 'country,' occurs 2 times.
# The word 'forty-eight,' occurs 1 times.
# The word 'fifty' occurs 30 times.
# The word 'yards' occurs 17 times.
# The word 'long.' occurs 7 times.
# The word 'said' occurs 247 times.
# The word 'six' occurs 23 times.
# The word 'killed' occurs 25 times.
# The word 'sixty' occurs 12 times.
# The word 'days."' occurs 1 times.
# The word '--OTHER' occurs 1 times.
# The word 'OR' occurs 4 times.
# The word 'OCTHER'S' occurs 1 times.
# The word 'VERBAL' occurs 1 times.
# The word 'NARRATIVE' occurs 1 times.
# The word 'TAKEN' occurs 1 times.
# The word 'DOWN' occurs 2 times.
# The word 'FROM' occurs 9 times.
# The word 'HIS' occurs 17 times.
# The word 'MOUTH' occurs 1 times.
# The word 'BY' occurs 15 times.
# The word 'KING' occurs 1 times.
# The word 'ALFRED,' occurs 1 times.
# The word 'A.D.' occurs 12 times.
# The word '890.' occurs 1 times.
# The word 'whereas' occurs 7 times.
# The word 'things,' occurs 26 times.
# The word 'whether' occurs 68 times.
# The word 'beast' occurs 3 times.
# The word 'vessel,' occurs 9 times.
# The word 'enter' occurs 9 times.
# The word 'dreadful' occurs 6 times.
# The word '(whale's)' occurs 1 times.
# The word 'lost' occurs 37 times.
# The word 'swallowed' occurs 11 times.
# The word 'sea-gudgeon' occurs 1 times.
# The word 'retires' occurs 1 times.
# The word 'security,' occurs 1 times.
# The word 'sleeps."' occurs 1 times.
# The word '--MONTAIGNE.' occurs 1 times.
# The word '--APOLOGY' occurs 1 times.
# The word 'FOR' occurs 6 times.
# The word 'RAIMOND' occurs 1 times.
# The word 'SEBOND.' occurs 1 times.
# The word '"Let' occurs 3 times.
# The word 'us' occurs 147 times.
# The word 'fly,' occurs 2 times.
# The word 'let' occurs 100 times.
# The word 'fly!' occurs 1 times.
# The word 'Old' occurs 10 times.
# The word 'Nick' occurs 1 times.
# The word 'me' occurs 339 times.
# The word 'if' occurs 396 times.
# The word 'described' occurs 4 times.
# The word 'noble' occurs 42 times.
# The word 'prophet' occurs 8 times.
# The word 'Moses' occurs 1 times.
# The word 'life' occurs 73 times.
# The word 'patient' occurs 6 times.
# The word 'Job."' occurs 1 times.
# The word '--RABELAIS.' occurs 1 times.
# The word '"This' occurs 2 times.
# The word 'whale's' occurs 76 times.
# The word 'liver' occurs 1 times.
# The word 'cartloads."' occurs 1 times.
# The word '--STOWE'S' occurs 1 times.
# The word 'ANNALS.' occurs 1 times.
# The word 'seas' occurs 37 times.
# The word 'seethe' occurs 2 times.
# The word 'like' occurs 544 times.
# The word 'boiling' occurs 15 times.
# The word 'pan."' occurs 1 times.
# The word '--LORD' occurs 1 times.
# The word 'BACON'S' occurs 1 times.
# The word 'VERSION' occurs 2 times.
# The word 'OF' occurs 49 times.
# The word 'THE' occurs 91 times.
# The word 'PSALMS.' occurs 1 times.
# The word '"Touching' occurs 1 times.
# The word 'bulk' occurs 22 times.
# The word 'ork' occurs 1 times.
# The word 'received' occurs 25 times.
# The word 'nothing' occurs 80 times.
# The word 'certain.' occurs 2 times.
# The word 'They' occurs 72 times.
# The word 'exceeding' occurs 12 times.
# The word 'fat,' occurs 1 times.
# The word 'insomuch' occurs 2 times.
# The word 'an' occurs 575 times.
# The word 'incredible' occurs 8 times.
# The word 'quantity' occurs 11 times.
# The word 'oil' occurs 41 times.
# The word 'extracted' occurs 5 times.
# The word 'whale."' occurs 11 times.
# The word '--IBID.' occurs 3 times.
# The word '"HISTORY' occurs 1 times.
# The word 'LIFE' occurs 1 times.
# The word 'AND' occurs 36 times.
# The word 'DEATH."' occurs 1 times.
# The word 'sovereignest' occurs 1 times.
# The word 'earth' occurs 10 times.
# The word 'parmacetti' occurs 2 times.
# The word 'inward' occurs 4 times.
# The word 'bruise."' occurs 1 times.
# The word '--KING' occurs 1 times.
# The word 'HENRY.' occurs 1 times.
# The word '"Very' occurs 4 times.
# The word '--HAMLET.' occurs 1 times.
# The word '"Which' occurs 1 times.
# The word 'secure,' occurs 2 times.
# The word 'skill' occurs 5 times.
# The word 'leach's' occurs 1 times.
# The word 'art' occurs 35 times.
# The word 'Mote' occurs 1 times.
# The word 'availle,' occurs 1 times.
# The word 'returne' occurs 1 times.
# The word 'againe' occurs 1 times.
# The word 'To' occurs 58 times.
# The word 'wound's' occurs 1 times.
# The word 'worker,' occurs 1 times.
# The word 'lowly' occurs 6 times.
# The word 'dart,' occurs 8 times.
# The word 'Dinting' occurs 1 times.
# The word 'breast,' occurs 4 times.
# The word 'bred' occurs 3 times.
# The word 'restless' occurs 3 times.
# The word 'paine,' occurs 1 times.
# The word 'Like' occurs 20 times.
# The word 'wounded' occurs 6 times.
# The word 'shore' occurs 10 times.
# The word 'flies' occurs 3 times.
# The word 'thro'' occurs 1 times.
# The word 'maine."' occurs 1 times.
# The word '--THE' occurs 1 times.
# The word 'FAERIE' occurs 1 times.
# The word 'QUEEN.' occurs 1 times.
# The word '"Immense' occurs 1 times.
# The word 'whales,' occurs 62 times.
# The word 'motion' occurs 13 times.
# The word 'vast' occurs 68 times.
# The word 'bodies' occurs 9 times.
# The word 'can' occurs 170 times.
# The word 'peaceful' occurs 6 times.
# The word 'calm' occurs 19 times.
# The word 'trouble' occurs 5 times.
# The word 'ocean' occurs 35 times.
# The word 'til' occurs 1 times.
# The word 'boil."' occurs 1 times.
# The word '--SIR' occurs 3 times.
# The word 'WILLIAM' occurs 2 times.
# The word 'DAVENANT.' occurs 1 times.
# The word 'PREFACE' occurs 1 times.
# The word 'TO' occurs 21 times.
# The word 'GONDIBERT.' occurs 1 times.
# The word '"What' occurs 29 times.
# The word 'spermacetti' occurs 1 times.
# The word 'is,' occurs 97 times.
# The word 'men' occurs 109 times.
# The word 'might' occurs 176 times.
# The word 'justly' occurs 3 times.
# The word 'doubt,' occurs 10 times.
# The word 'since' occurs 54 times.
# The word 'learned' occurs 21 times.
# The word 'Hosmannus' occurs 1 times.
# The word 'work' occurs 36 times.
# The word 'thirty' occurs 23 times.
# The word 'years,' occurs 14 times.
# The word 'saith' occurs 5 times.
# The word 'plainly,' occurs 2 times.
# The word 'Nescio' occurs 1 times.
# The word 'quid' occurs 1 times.
# The word 'sit."' occurs 1 times.
# The word 'T.' occurs 5 times.
# The word 'BROWNE.' occurs 1 times.
# The word 'SPERMA' occurs 2 times.
# The word 'CETI' occurs 2 times.
# The word 'WHALE.' occurs 5 times.
# The word 'VIDE' occurs 1 times.
# The word 'V.' occurs 4 times.
# The word 'E.' occurs 2 times.
# The word '"Like' occurs 2 times.
# The word 'Spencer's' occurs 1 times.
# The word 'Talus' occurs 1 times.
# The word 'modern' occurs 17 times.
# The word 'flail' occurs 1 times.
# The word 'threatens' occurs 1 times.
# The word 'ruin' occurs 3 times.
# The word 'ponderous' occurs 13 times.
# The word 'tail.' occurs 7 times.
# The word 'Their' occurs 6 times.
# The word 'fixed' occurs 31 times.
# The word 'jav'lins' occurs 1 times.
# The word 'side' occurs 95 times.
# The word 'wears,' occurs 1 times.
# The word 'And' occurs 321 times.
# The word 'back' occurs 88 times.
# The word 'grove' occurs 1 times.
# The word 'pikes' occurs 2 times.
# The word 'appears."' occurs 1 times.
# The word '--WALLER'S' occurs 1 times.
# The word 'BATTLE' occurs 2 times.
# The word 'SUMMER' occurs 1 times.
# The word 'ISLANDS.' occurs 1 times.
# The word '"By' occurs 3 times.
# The word 'Commonwealth' occurs 1 times.
# The word 'State--(in' occurs 1 times.
# The word 'Latin,' occurs 1 times.
# The word 'Civitas)' occurs 1 times.
# The word 'artificial' occurs 5 times.
# The word 'man."' occurs 7 times.
# The word '--OPENING' occurs 1 times.
# The word 'SENTENCE' occurs 1 times.
# The word 'HOBBES'S' occurs 1 times.
# The word 'LEVIATHAN.' occurs 1 times.
# The word '"Silly' occurs 1 times.
# The word 'Mansoul' occurs 1 times.
# The word 'without' occurs 145 times.
# The word 'chewing,' occurs 1 times.
# The word 'sprat' occurs 1 times.
# The word 'mouth' occurs 20 times.
# The word '--PILGRIM'S' occurs 1 times.
# The word 'PROGRESS.' occurs 1 times.
# The word '"That' occurs 5 times.
# The word 'works' occurs 7 times.
# The word 'Created' occurs 1 times.
# The word 'hugest' occurs 3 times.
# The word 'swim' occurs 16 times.
# The word 'stream."' occurs 1 times.
# The word '--PARADISE' occurs 1 times.
# The word 'LOST.' occurs 1 times.
# The word '---"There' occurs 1 times.
# The word 'Hugest' occurs 1 times.
# The word 'living' occurs 66 times.
# The word 'creatures,' occurs 9 times.
# The word 'Stretched' occurs 1 times.
# The word 'promontory' occurs 4 times.
# The word 'sleeps' occurs 6 times.
# The word 'swims,' occurs 2 times.
# The word 'seems' occurs 76 times.
# The word 'moving' occurs 12 times.
# The word 'land;' occurs 6 times.
# The word 'gills' occurs 2 times.
# The word 'Draws' occurs 1 times.
# The word 'in,' occurs 34 times.
# The word 'breath' occurs 10 times.
# The word 'spouts' occurs 11 times.
# The word 'mighty' occurs 43 times.
# The word 'water,' occurs 51 times.
# The word 'swimming' occurs 19 times.
# The word 'them."' occurs 3 times.
# The word '--FULLLER'S' occurs 1 times.
# The word 'PROFANE' occurs 1 times.
# The word 'HOLY' occurs 1 times.
# The word 'STATE.' occurs 1 times.
# The word '"So' occurs 4 times.
# The word 'close' occurs 46 times.
# The word 'behind' occurs 39 times.
# The word 'lie' occurs 25 times.
# The word 'huge' occurs 27 times.
# The word 'attend' occurs 9 times.
# The word 'prey,' occurs 5 times.
# The word 'give' occurs 65 times.
# The word 'chance,' occurs 6 times.
# The word 'fry,' occurs 1 times.
# The word 'Which' occurs 5 times.
# The word 'gaping' occurs 3 times.
# The word 'jaws' occurs 20 times.
# The word 'mistake' occurs 7 times.
# The word 'way."' occurs 3 times.
# The word '--DRYDEN'S' occurs 1 times.
# The word 'ANNUS' occurs 1 times.
# The word 'MIRABILIS.' occurs 1 times.
# The word 'floating' occurs 24 times.
# The word 'stern' occurs 17 times.
# The word 'ship,' occurs 78 times.
# The word 'they' occurs 568 times.
# The word 'cut' occurs 39 times.
# The word 'off' occurs 164 times.
# The word 'head,' occurs 68 times.
# The word 'tow' occurs 9 times.
# The word 'boat' occurs 125 times.
# The word 'near' occurs 58 times.
# The word 'come;' occurs 7 times.
# The word 'aground' occurs 1 times.
# The word 'twelve' occurs 14 times.
# The word 'thirteen' occurs 2 times.
# The word 'feet' occurs 90 times.
# The word 'water."' occurs 2 times.
# The word '--THOMAS' occurs 3 times.
# The word 'EDGE'S' occurs 1 times.
# The word 'TEN' occurs 1 times.
# The word 'VOYAGES' occurs 2 times.
# The word 'SPITZBERGEN,' occurs 1 times.
# The word 'IN' occurs 19 times.
# The word 'PURCHAS.' occurs 1 times.
# The word 'way' occurs 151 times.
# The word 'saw' occurs 101 times.
# The word 'sporting' occurs 4 times.
# The word 'ocean,' occurs 16 times.
# The word 'wantonness' occurs 1 times.
# The word 'fuzzing' occurs 1 times.
# The word 'water' occurs 71 times.
# The word 'pipes' occurs 5 times.
# The word 'vents,' occurs 1 times.
# The word 'nature' occurs 21 times.
# The word 'placed' occurs 36 times.
# The word 'shoulders."' occurs 1 times.
# The word 'HERBERT'S' occurs 1 times.
# The word 'INTO' occurs 1 times.
# The word 'ASIA' occurs 1 times.
# The word 'AFRICA.' occurs 1 times.
# The word 'HARRIS' occurs 2 times.
# The word 'COLL.' occurs 2 times.
# The word '"Here' occurs 2 times.
# The word 'such' occurs 325 times.
# The word 'troops' occurs 2 times.
# The word 'forced' occurs 16 times.
# The word 'proceed' occurs 10 times.
# The word 'deal' occurs 11 times.
# The word 'caution' occurs 1 times.
# The word 'fear' occurs 20 times.
# The word 'should' occurs 180 times.
# The word 'run' occurs 41 times.
# The word 'ship' occurs 227 times.
# The word '--SCHOUTEN'S' occurs 1 times.
# The word 'SIXTH' occurs 1 times.
# The word 'CIRCUMNAVIGATION.' occurs 1 times.
# The word '"We' occurs 4 times.
# The word 'set' occurs 60 times.
# The word 'sail' occurs 51 times.
# The word 'Elbe,' occurs 1 times.
# The word 'wind' occurs 34 times.
# The word 'N.E.' occurs 1 times.
# The word 'Jonas-in-the-Whale.' occurs 1 times.
# The word 'Some' occurs 34 times.
# The word 'can't' occurs 23 times.
# The word 'open' occurs 56 times.
# The word 'fable.' occurs 2 times.
# The word 'frequently' occurs 14 times.
# The word 'climb' occurs 3 times.
# The word 'masts' occurs 21 times.
# The word 'whale,' occurs 172 times.
# The word 'first' occurs 196 times.
# The word 'discoverer' occurs 1 times.
# The word 'ducat' occurs 1 times.
# The word 'pains.' occurs 2 times.
# The word 'told' occurs 39 times.
# The word 'taken' occurs 47 times.
# The word 'Shetland,' occurs 1 times.
# The word 'above' occurs 45 times.
# The word 'barrel' occurs 1 times.
# The word 'herrings' occurs 1 times.
# The word 'belly.' occurs 2 times.
# The word 'harpooneers' occurs 34 times.
# The word 'caught' occurs 40 times.
# The word 'once' occurs 122 times.
# The word 'Spitzbergen' occurs 4 times.
# The word 'white' occurs 150 times.
# The word 'over."' occurs 1 times.
# The word '--A' occurs 2 times.
# The word 'VOYAGE' occurs 7 times.
# The word 'GREENLAND,' occurs 1 times.
# The word '1671' occurs 1 times.
# The word '"Several' occurs 1 times.
# The word 'come' occurs 118 times.
# The word 'coast' occurs 19 times.
# The word '(Fife)' occurs 1 times.
# The word 'Anno' occurs 1 times.
# The word '1652,' occurs 1 times.
# The word 'eighty' occurs 3 times.
# The word 'whale-bone' occurs 4 times.
# The word 'kind' occurs 23 times.
# The word '(as' occurs 5 times.
# The word 'informed),' occurs 1 times.
# The word 'oil,' occurs 21 times.
# The word 'did' occurs 221 times.
# The word 'afford' occurs 9 times.
# The word '500' occurs 2 times.
# The word 'weight' occurs 13 times.
# The word 'baleen.' occurs 3 times.
# The word 'stand' occurs 61 times.
# The word 'gate' occurs 3 times.
# The word 'garden' occurs 3 times.
# The word 'Pitferren."' occurs 1 times.
# The word '--SIBBALD'S' occurs 1 times.
# The word 'FIFE' occurs 1 times.
# The word 'KINROSS.' occurs 1 times.
# The word '"Myself' occurs 1 times.
# The word 'agreed' occurs 3 times.
# The word 'try' occurs 26 times.
# The word 'master' occurs 8 times.
# The word 'kill' occurs 21 times.
# The word 'Sperma-ceti' occurs 1 times.
# The word 'never' occurs 188 times.
# The word 'hear' occurs 48 times.
# The word 'sort' occurs 139 times.
# The word 'man,' occurs 93 times.
# The word 'fierceness' occurs 1 times.
# The word 'swiftness."' occurs 1 times.
# The word '--RICHARD' occurs 1 times.
# The word 'STRAFFORD'S' occurs 1 times.
# The word 'LETTER' occurs 1 times.
# The word 'BERMUDAS.' occurs 1 times.
# The word 'PHIL.' occurs 1 times.
# The word 'TRANS.' occurs 1 times.
# The word '1668.' occurs 1 times.
# The word '"Whales' occurs 1 times.
# The word 'God's' occurs 16 times.
# The word 'voice' occurs 32 times.
# The word 'obey."' occurs 1 times.
# The word '--N.' occurs 1 times.
# The word 'PRIMER.' occurs 1 times.
# The word 'abundance' occurs 4 times.
# The word 'large' occurs 63 times.
# The word 'being' occurs 204 times.
# The word 'those' occurs 294 times.
# The word 'southern' occurs 5 times.
# The word 'seas,' occurs 19 times.
# The word 'may' occurs 208 times.
# The word 'say,' occurs 92 times.
# The word 'hundred' occurs 50 times.
# The word 'one;' occurs 15 times.
# The word 'than' occurs 307 times.
# The word 'northward' occurs 2 times.
# The word 'us."' occurs 4 times.
# The word '--CAPTAIN' occurs 1 times.
# The word 'COWLEY'S' occurs 1 times.
# The word 'ROUND' occurs 2 times.
# The word 'GLOBE,' occurs 2 times.
# The word '1729.' occurs 1 times.
# The word '"...' occurs 1 times.
# The word 'frequendy' occurs 1 times.
# The word 'attended' occurs 6 times.
# The word 'insupportable' occurs 1 times.
# The word 'smell,' occurs 2 times.
# The word 'bring' occurs 17 times.
# The word 'disorder' occurs 1 times.
# The word 'brain."' occurs 1 times.
# The word '--ULLOA'S' occurs 1 times.
# The word 'SOUTH' occurs 1 times.
# The word 'AMERICA.' occurs 1 times.
# The word '"To' occurs 2 times.
# The word 'chosen' occurs 3 times.
# The word 'sylphs' occurs 1 times.
# The word 'special' occurs 14 times.
# The word 'note,' occurs 2 times.
# The word 'We' occurs 38 times.
# The word 'trust' occurs 3 times.
# The word 'important' occurs 17 times.
# The word 'charge,' occurs 1 times.
# The word 'petticoat.' occurs 1 times.
# The word 'Oft' occurs 1 times.
# The word 'seven-fold' occurs 1 times.
# The word 'fence' occurs 2 times.
# The word 'fail,' occurs 2 times.
# The word 'Tho'' occurs 1 times.
# The word 'stuffed' occurs 5 times.
# The word 'hoops' occurs 6 times.
# The word 'armed' occurs 10 times.
# The word 'ribs' occurs 11 times.
# The word '--RAPE' occurs 1 times.
# The word 'LOCK.' occurs 1 times.
# The word '"If' occurs 6 times.
# The word 'compare' occurs 6 times.
# The word 'land' occurs 35 times.
# The word 'animals' occurs 5 times.
# The word 'respect' occurs 14 times.
# The word 'magnitude,' occurs 6 times.
# The word 'abode' occurs 1 times.
# The word 'deep,' occurs 13 times.
# The word 'appear' occurs 5 times.
# The word 'contemptible' occurs 4 times.
# The word 'comparison.' occurs 3 times.
# The word 'doubtless' occurs 6 times.
# The word 'largest' occurs 17 times.
# The word 'creation."' occurs 1 times.
# The word '--GOLDSMITH,' occurs 1 times.
# The word 'NAT.' occurs 1 times.
# The word 'HIST.' occurs 1 times.
# The word 'write' occurs 4 times.
# The word 'fable' occurs 1 times.
# The word 'little' occurs 232 times.
# The word 'fishes,' occurs 1 times.
# The word 'make' occurs 104 times.
# The word 'speak' occurs 31 times.
# The word 'wales."' occurs 1 times.
# The word '--GOLDSMITH' occurs 1 times.
# The word 'JOHNSON.' occurs 1 times.
# The word 'afternoon' occurs 5 times.
# The word 'supposed' occurs 14 times.
# The word 'rock,' occurs 1 times.
# The word 'found' occurs 105 times.
# The word 'dead' occurs 67 times.
# The word 'Asiatics' occurs 2 times.
# The word 'killed,' occurs 3 times.
# The word 'then' occurs 336 times.
# The word 'towing' occurs 12 times.
# The word 'ashore.' occurs 8 times.
# The word 'seemed' occurs 273 times.
# The word 'endeavor' occurs 3 times.
# The word 'conceal' occurs 2 times.
# The word 'themselves' occurs 44 times.
# The word 'order' occurs 48 times.
# The word 'avoid' occurs 6 times.
# The word '--COOK'S' occurs 1 times.
# The word 'VOYAGES.' occurs 1 times.
# The word 'larger' occurs 8 times.
# The word 'seldom' occurs 24 times.
# The word 'venture' occurs 5 times.
# The word 'attack.' occurs 2 times.
# The word 'dread' occurs 9 times.
# The word 'them,' occurs 83 times.
# The word 'afraid' occurs 13 times.
# The word 'mention' occurs 13 times.
# The word 'names,' occurs 1 times.
# The word 'carry' occurs 25 times.
# The word 'dung,' occurs 1 times.
# The word 'lime-stone,' occurs 1 times.
# The word 'juniper-wood,' occurs 1 times.
# The word 'articles' occurs 4 times.
# The word 'same' occurs 199 times.
# The word 'boats,' occurs 31 times.
# The word 'terrify' occurs 3 times.
# The word 'prevent' occurs 6 times.
# The word 'approach."' occurs 1 times.
# The word '--UNO' occurs 1 times.
# The word 'VON' occurs 1 times.
# The word 'TROIL'S' occurs 1 times.
# The word 'LETTERS' occurs 1 times.
# The word 'ON' occurs 11 times.
# The word 'BANKS'S' occurs 1 times.
# The word 'SOLANDER'S' occurs 1 times.
# The word 'ICELAND' occurs 2 times.
# The word '1772.' occurs 1 times.
# The word 'Spermacetti' occurs 2 times.
# The word 'Whale' occurs 125 times.
# The word 'Nantuckois,' occurs 1 times.
# The word 'active,' occurs 2 times.
# The word 'fierce' occurs 10 times.
# The word 'animal,' occurs 4 times.
# The word 'requires' occurs 7 times.
# The word 'address' occurs 4 times.
# The word 'boldness' occurs 2 times.
# The word 'fishermen."' occurs 1 times.
# The word 'JEFFERSON'S' occurs 1 times.
# The word 'WHALE' occurs 11 times.
# The word 'MEMORIAL' occurs 1 times.
# The word 'FRENCH' occurs 4 times.
# The word 'MINISTER' occurs 1 times.
# The word '1778.' occurs 1 times.
# The word 'pray,' occurs 1 times.
# The word 'sir,' occurs 45 times.
# The word 'equal' occurs 12 times.
# The word 'it?"' occurs 8 times.
# The word '--EDMUND' occurs 2 times.
# The word 'BURKE'S' occurs 1 times.
# The word 'REFERENCE' occurs 1 times.
# The word 'PARLIAMENT' occurs 1 times.
# The word 'NANTUCKET' occurs 6 times.
# The word 'WHALE-FISHERY.' occurs 1 times.
# The word '"Spain--a' occurs 1 times.
# The word 'stranded' occurs 7 times.
# The word 'shores' occurs 3 times.
# The word 'Europe."' occurs 1 times.
# The word 'BURKE.' occurs 1 times.
# The word '(SOMEWHERE.)' occurs 1 times.
# The word '"A' occurs 17 times.
# The word 'tenth' occurs 4 times.
# The word 'branch' occurs 4 times.
# The word 'king's' occurs 5 times.
# The word 'ordinary' occurs 18 times.
# The word 'revenue,' occurs 1 times.
# The word 'grounded' occurs 3 times.
# The word 'consideration' occurs 6 times.
# The word 'guarding' occurs 1 times.
# The word 'protecting' occurs 1 times.
# The word 'pirates' occurs 7 times.
# The word 'robbers,' occurs 1 times.
# The word 'right' occurs 65 times.
# The word 'royal' occurs 25 times.
# The word 'fish,' occurs 28 times.
# The word 'sturgeon.' occurs 1 times.
# The word 'these,' occurs 13 times.
# The word 'either' occurs 28 times.
# The word 'thrown' occurs 24 times.
# The word 'ashore' occurs 12 times.
# The word 'coast,' occurs 11 times.
# The word 'property' occurs 6 times.
# The word 'king."' occurs 1 times.
# The word '--BLACKSTONE.' occurs 1 times.
# The word '"Soon' occurs 1 times.
# The word 'sport' occurs 1 times.
# The word 'death' occurs 26 times.
# The word 'crews' occurs 10 times.
# The word 'repair:' occurs 1 times.
# The word 'Rodmond' occurs 1 times.
# The word 'unerring' occurs 3 times.
# The word 'o'er' occurs 1 times.
# The word 'head' occurs 138 times.
# The word 'suspends' occurs 1 times.
# The word 'barbed' occurs 6 times.
# The word 'steel,' occurs 3 times.
# The word 'turn' occurs 49 times.
# The word 'attends."' occurs 1 times.
# The word '--FALCONER'S' occurs 1 times.
# The word 'SHIPWRECK.' occurs 1 times.
# The word '"Bright' occurs 1 times.
# The word 'shone' occurs 3 times.
# The word 'roofs,' occurs 1 times.
# The word 'domes,' occurs 1 times.
# The word 'spires,' occurs 2 times.
# The word 'rockets' occurs 1 times.
# The word 'blew' occurs 8 times.
# The word 'self' occurs 2 times.
# The word 'driven,' occurs 3 times.
# The word 'hang' occurs 5 times.
# The word 'momentary' occurs 2 times.
# The word 'fire' occurs 29 times.
# The word 'Around' occurs 1 times.
# The word 'vault' occurs 1 times.
# The word 'heaven.' occurs 9 times.
# The word 'compare,' occurs 1 times.
# The word 'serves' occurs 2 times.
# The word 'high,' occurs 9 times.
# The word 'Up-spouted' occurs 1 times.
# The word 'air,' occurs 39 times.
# The word 'express' occurs 8 times.
# The word 'unwieldy' occurs 1 times.
# The word 'joy."' occurs 1 times.
# The word '--COWPER,' occurs 1 times.
# The word 'QUEEN'S' occurs 1 times.
# The word 'VISIT' occurs 1 times.
# The word 'LONDON.' occurs 1 times.
# The word '"Ten' occurs 1 times.
# The word 'fifteen' occurs 9 times.
# The word 'gallons' occurs 5 times.
# The word 'blood' occurs 29 times.
# The word 'heart' occurs 52 times.
# The word 'stroke,' occurs 3 times.
# The word 'immense' occurs 13 times.
# The word 'velocity."' occurs 1 times.
# The word '--JOHN' occurs 1 times.
# The word 'HUNTER'S' occurs 1 times.
# The word 'ACCOUNT' occurs 2 times.
# The word 'DISSECTION' occurs 1 times.
# The word 'A' occurs 125 times.
# The word '(A' occurs 1 times.
# The word 'SMALL' occurs 1 times.
# The word 'SIZED' occurs 1 times.
# The word 'ONE.)' occurs 1 times.
# The word 'aorta' occurs 1 times.
# The word 'bore' occurs 15 times.
# The word 'main' occurs 12 times.
# The word 'pipe' occurs 14 times.
# The word 'water-works' occurs 1 times.
# The word 'London' occurs 7 times.
# The word 'Bridge,' occurs 2 times.
# The word 'roaring' occurs 9 times.
# The word 'its' occurs 369 times.
# The word 'passage' occurs 27 times.
# The word 'inferior' occurs 10 times.
# The word 'impetus' occurs 2 times.
# The word 'velocity' occurs 6 times.
# The word 'gushing' occurs 1 times.
# The word 'heart."' occurs 1 times.
# The word '--PALEY'S' occurs 1 times.
# The word 'THEOLOGY.' occurs 1 times.
# The word 'mammiferous' occurs 1 times.
# The word 'hind' occurs 1 times.
# The word 'feet."' occurs 1 times.
# The word '--BARON' occurs 1 times.
# The word 'CUVIER.' occurs 1 times.
# The word '40' occurs 2 times.
# The word 'degrees' occurs 5 times.
# The word 'south,' occurs 2 times.
# The word 'Whales,' occurs 9 times.
# The word 'till' occurs 117 times.
# The word 'May,' occurs 2 times.
# The word 'covered' occurs 9 times.
# The word '--COLNETT'S' occurs 1 times.
# The word 'PURPOSE' occurs 1 times.
# The word 'EXTENDING' occurs 1 times.
# The word 'SPERMACETI' occurs 1 times.
# The word 'FISHERY.' occurs 1 times.
# The word 'free' occurs 22 times.
# The word 'element' occurs 9 times.
# The word 'beneath' occurs 66 times.
# The word 'swam,' occurs 3 times.
# The word 'Floundered' occurs 1 times.
# The word 'dived,' occurs 2 times.
# The word 'play,' occurs 2 times.
# The word 'chace,' occurs 1 times.
# The word 'battle,' occurs 3 times.
# The word 'Fishes' occurs 1 times.
# The word 'colour,' occurs 7 times.
# The word 'form,' occurs 8 times.
# The word 'kind;' occurs 2 times.
# The word 'language' occurs 1 times.
# The word 'cannot' occurs 64 times.
# The word 'paint,' occurs 1 times.
# The word 'mariner' occurs 10 times.
# The word 'Had' occurs 12 times.
# The word 'seen;' occurs 9 times.
# The word 'insect' occurs 2 times.
# The word 'millions' occurs 7 times.
# The word 'peopling' occurs 1 times.
# The word 'wave:' occurs 1 times.
# The word 'Gather'd' occurs 1 times.
# The word 'shoals' occurs 5 times.
# The word 'immense,' occurs 1 times.
# The word 'islands,' occurs 6 times.
# The word 'Led' occurs 1 times.
# The word 'mysterious' occurs 9 times.
# The word 'instincts' occurs 1 times.
# The word 'waste' occurs 3 times.
# The word 'trackless' occurs 1 times.
# The word 'region,' occurs 1 times.
# The word 'though' occurs 272 times.
# The word 'Assaulted' occurs 1 times.
# The word 'voracious' occurs 1 times.
# The word 'enemies,' occurs 1 times.
# The word 'sharks,' occurs 14 times.
# The word 'monsters,' occurs 1 times.
# The word 'arm'd' occurs 1 times.
# The word 'front' occurs 18 times.
# The word 'jaw,' occurs 14 times.
# The word 'With' occurs 54 times.
# The word 'swords,' occurs 2 times.
# The word 'saws,' occurs 1 times.
# The word 'spiral' occurs 1 times.
# The word 'horns,' occurs 1 times.
# The word 'hooked' occurs 4 times.
# The word 'fangs."' occurs 1 times.
# The word '--MONTGOMERY'S' occurs 1 times.
# The word 'WORLD' occurs 1 times.
# The word 'BEFORE' occurs 2 times.
# The word 'FLOOD.' occurs 1 times.
# The word '"Io!' occurs 1 times.
# The word 'Paean!' occurs 1 times.
# The word 'Io!' occurs 1 times.
# The word 'sing.' occurs 1 times.
# The word 'finny' occurs 2 times.
# The word 'people's' occurs 5 times.
# The word 'Not' occurs 41 times.
# The word 'mightier' occurs 1 times.
# The word 'In' occurs 215 times.
# The word 'Atlantic' occurs 10 times.
# The word 'is;' occurs 10 times.
# The word 'fatter' occurs 1 times.
# The word 'he,' occurs 17 times.
# The word 'Flounders' occurs 1 times.
# The word 'round' occurs 209 times.
# The word 'Polar' occurs 11 times.
# The word 'Sea."' occurs 2 times.
# The word '--CHARLES' occurs 1 times.
# The word 'LAMB'S' occurs 1 times.
# The word 'TRIUMPH' occurs 1 times.
# The word 'year' occurs 14 times.
# The word '1690' occurs 1 times.
# The word 'persons' occurs 6 times.
# The word 'high' occurs 80 times.
# The word 'hill' occurs 5 times.
# The word 'observing' occurs 7 times.
# The word 'spouting' occurs 10 times.
# The word 'each' occurs 125 times.
# The word 'other,' occurs 33 times.
# The word 'observed:' occurs 1 times.
# The word 'there--pointing' occurs 1 times.
# The word 'sea--is' occurs 1 times.
# The word 'green' occurs 36 times.
# The word 'pasture' occurs 3 times.
# The word 'where' occurs 167 times.
# The word 'children's' occurs 1 times.
# The word 'grand-children' occurs 1 times.
# The word 'bread."' occurs 1 times.
# The word '--OBED' occurs 1 times.
# The word 'MACY'S' occurs 1 times.
# The word 'HISTORY' occurs 2 times.
# The word 'NANTUCKET.' occurs 2 times.
# The word '"I' occurs 88 times.
# The word 'built' occurs 6 times.
# The word 'cottage' occurs 2 times.
# The word 'Susan' occurs 1 times.
# The word 'myself' occurs 42 times.
# The word 'gateway' occurs 2 times.
# The word 'form' occurs 27 times.
# The word 'Gothic' occurs 4 times.
# The word 'Arch,' occurs 2 times.
# The word 'setting' occurs 11 times.
# The word 'jaw' occurs 20 times.
# The word 'bones."' occurs 1 times.
# The word '--HAWTHORNE'S' occurs 1 times.
# The word 'TWICE' occurs 1 times.
# The word 'TOLD' occurs 2 times.
# The word 'TALES.' occurs 1 times.
# The word '"She' occurs 1 times.
# The word 'bespeak' occurs 1 times.
# The word 'monument' occurs 1 times.
# The word 'her' occurs 274 times.
# The word 'love,' occurs 5 times.
# The word 'Pacific' occurs 12 times.
# The word 'less' occurs 49 times.
# The word 'forty' occurs 19 times.
# The word 'years' occurs 60 times.
# The word 'ago."' occurs 1 times.
# The word '"No,' occurs 12 times.
# The word 'Sir,' occurs 3 times.
# The word ''tis' occurs 15 times.
# The word 'Right' occurs 48 times.
# The word 'Whale,"' occurs 3 times.
# The word 'answered' occurs 12 times.
# The word 'Tom;' occurs 1 times.
# The word 'sprout;' occurs 1 times.
# The word 'threw' occurs 10 times.
# The word 'pair' occurs 11 times.
# The word 'pretty' occurs 28 times.
# The word 'rainbows' occurs 3 times.
# The word 'Christian' occurs 15 times.
# The word 'wish' occurs 12 times.
# The word 'look' occurs 98 times.
# The word 'at.' occurs 4 times.
# The word 'He's' occurs 12 times.
# The word 'raal' occurs 1 times.
# The word 'oil-butt,' occurs 2 times.
# The word 'fellow!"' occurs 1 times.
# The word '--COOPER'S' occurs 1 times.
# The word 'PILOT.' occurs 1 times.
# The word 'papers' occurs 4 times.
# The word 'Berlin' occurs 1 times.
# The word 'Gazette' occurs 1 times.
# The word 'introduced' occurs 5 times.
# The word 'stage' occurs 6 times.
# The word 'there."' occurs 4 times.
# The word '--ECKERMANN'S' occurs 1 times.
# The word 'CONVERSATIONS' occurs 1 times.
# The word 'WITH' occurs 3 times.
# The word 'GOETHE.' occurs 1 times.
# The word '"My' occurs 7 times.
# The word 'God!' occurs 15 times.
# The word 'Mr.' occurs 50 times.
# The word 'Chace,' occurs 2 times.
# The word 'matter?"' occurs 1 times.
# The word 'answered,' occurs 7 times.
# The word '"we' occurs 2 times.
# The word 'stove' occurs 19 times.
# The word '--"NARRATIVE' occurs 2 times.
# The word 'SHIPWRECK' occurs 1 times.
# The word 'SHIP' occurs 2 times.
# The word 'ESSEX' occurs 1 times.
# The word 'NANTUCKET,' occurs 2 times.
# The word 'WHICH' occurs 2 times.
# The word 'WAS' occurs 1 times.
# The word 'ATTACKED' occurs 1 times.
# The word 'FINALLY' occurs 1 times.
# The word 'DESTROYED' occurs 1 times.
# The word 'LARGE' occurs 2 times.
# The word 'SPERM' occurs 4 times.
# The word 'PACIFIC' occurs 1 times.
# The word 'OCEAN."' occurs 1 times.
# The word 'OWEN' occurs 1 times.
# The word 'CHACE' occurs 1 times.
# The word 'FIRST' occurs 1 times.
# The word 'MATE' occurs 1 times.
# The word 'SAID' occurs 1 times.
# The word 'VESSEL.' occurs 1 times.
# The word 'NEW' occurs 2 times.
# The word 'YORK,' occurs 1 times.
# The word '1821.' occurs 1 times.
# The word 'sat' occurs 40 times.
# The word 'shrouds' occurs 2 times.
# The word 'night,' occurs 45 times.
# The word 'piping' occurs 1 times.
# The word 'free;' occurs 3 times.
# The word 'Now' occurs 44 times.
# The word 'bright,' occurs 4 times.
# The word 'now' occurs 457 times.
# The word 'dimmed,' occurs 1 times.
# The word 'moonlight' occurs 4 times.
# The word 'pale,' occurs 5 times.
# The word 'phospher' occurs 1 times.
# The word 'gleamed' occurs 4 times.
# The word 'wake' occurs 15 times.
# The word 'floundered' occurs 2 times.
# The word '--ELIZABETH' occurs 1 times.
# The word 'OAKES' occurs 1 times.
# The word 'SMITH.' occurs 1 times.
# The word 'line' occurs 60 times.
# The word 'withdrawn' occurs 4 times.
# The word 'boats' occurs 85 times.
# The word 'engaged' occurs 17 times.
# The word 'capture' occurs 11 times.
# The word 'amounted' occurs 1 times.
# The word '10,440' occurs 1 times.
# The word 'nearly' occurs 33 times.
# The word 'English' occurs 41 times.
# The word 'miles.' occurs 3 times.
# The word '"Sometimes' occurs 1 times.
# The word 'shakes' occurs 5 times.
# The word 'tremendous' occurs 9 times.
# The word 'tail' occurs 30 times.
# The word 'which,' occurs 77 times.
# The word 'cracking' occurs 3 times.
# The word 'whip,' occurs 3 times.
# The word 'resounds' occurs 2 times.
# The word 'distance' occurs 28 times.
# The word 'three' occurs 224 times.
# The word 'miles."' occurs 1 times.
# The word '--SCORESBY.' occurs 1 times.
# The word '"Mad' occurs 1 times.
# The word 'agonies' occurs 1 times.
# The word 'endures' occurs 1 times.
# The word 'fresh' occurs 25 times.
# The word 'attacks,' occurs 1 times.
# The word 'infuriated' occurs 1 times.
# The word 'Sperm' occurs 129 times.
# The word 'rolls' occurs 9 times.
# The word 'over' occurs 359 times.
# The word 'over;' occurs 3 times.
# The word 'rears' occurs 1 times.
# ...
# The word 'new-made' occurs 1 times.
# The word 'summer-house' occurs 1 times.
# The word 'fairer' occurs 1 times.
# The word 'thinks;' occurs 1 times.
# The word 'feels;' occurs 1 times.
# The word 'THAT'S' occurs 1 times.
# The word 'think's' occurs 1 times.
# The word 'privilege.' occurs 1 times.
# The word 'calmness;' occurs 1 times.
# The word 'throb,' occurs 1 times.
# The word 'calm--frozen' occurs 1 times.
# The word 'growing,' occurs 1 times.
# The word 'clefts' occurs 1 times.
# The word 'Vesuvius' occurs 1 times.
# The word 'lava.' occurs 1 times.
# The word 'prison' occurs 1 times.
# The word 'corridors' occurs 1 times.
# The word 'wards' occurs 1 times.
# The word 'hospitals,' occurs 1 times.
# The word 'ventilated' occurs 1 times.
# The word 'fleeces.' occurs 1 times.
# The word 'it!--it's' occurs 1 times.
# The word 'tainted.' occurs 1 times.
# The word 'wicked,' occurs 1 times.
# The word 'cave,' occurs 1 times.
# The word 'slink' occurs 1 times.
# The word 'braver' occurs 1 times.
# The word 'thing--a' occurs 1 times.
# The word 'THAT.' occurs 1 times.
# The word 'exasperate' occurs 1 times.
# The word 'bodiless,' occurs 1 times.
# The word 'bodiless' occurs 1 times.
# The word 'special,' occurs 1 times.
# The word 'difference!' occurs 1 times.
# The word 'Trade' occurs 1 times.
# The word 'Winds,' occurs 1 times.
# The word 'steadfast,' occurs 1 times.
# The word 'mildness;' occurs 1 times.
# The word 'veer' occurs 1 times.
# The word 'baser' occurs 1 times.
# The word 'tack,' occurs 1 times.
# The word 'Mississippies' occurs 1 times.
# The word 'Poles!' occurs 1 times.
# The word 'Trades' occurs 1 times.
# The word 'Trades,' occurs 1 times.
# The word 'them--something' occurs 1 times.
# The word 'unchangeable,' occurs 1 times.
# The word 'along!' occurs 1 times.
# The word '"Nothing!' occurs 1 times.
# The word 'a-begging!' occurs 1 times.
# The word 'oversailed' occurs 1 times.
# The word 'start?' occurs 1 times.
# The word 'HIM--that's' occurs 1 times.
# The word 'bad;' occurs 1 times.
# The word 'lines--the' occurs 1 times.
# The word 'towing.' occurs 1 times.
# The word 'About!' occurs 1 times.
# The word 'about!' occurs 1 times.
# The word 'outs!' occurs 1 times.
# The word 'braces!"' occurs 1 times.
# The word 'quarter,' occurs 1 times.
# The word 'reverse' occurs 1 times.
# The word 'rechurned' occurs 1 times.
# The word '"Against' occurs 1 times.
# The word 'jaw,"' occurs 1 times.
# The word 'new-hauled' occurs 1 times.
# The word 'main-brace' occurs 1 times.
# The word 'misdoubt' occurs 1 times.
# The word 'basket.' occurs 1 times.
# The word 'soon."' occurs 1 times.
# The word 'high.' occurs 1 times.
# The word 'gold-beaten' occurs 1 times.
# The word 'suspense.' occurs 1 times.
# The word 'voiced' occurs 1 times.
# The word '"Forehead' occurs 1 times.
# The word 'there!--brace' occurs 1 times.
# The word 'wind's' occurs 1 times.
# The word 'top-maul!' occurs 1 times.
# The word 'wink' occurs 1 times.
# The word 'sand-hills' occurs 1 times.
# The word 'same!--the' occurs 2 times.
# The word 'leewardings!' occurs 1 times.
# The word 'somewhere--to' occurs 1 times.
# The word 'Leeward!' occurs 1 times.
# The word 'bitterer' occurs 1 times.
# The word 'bye,' occurs 2 times.
# The word 'mast-head!' occurs 1 times.
# The word 'this?--green?' occurs 1 times.
# The word 'tiny' occurs 1 times.
# The word 'matter's.' occurs 1 times.
# The word 'hulls,' occurs 1 times.
# The word 'fathers.' occurs 1 times.
# The word 'pilot;' occurs 1 times.
# The word 'again?' occurs 1 times.
# The word 'where?' occurs 1 times.
# The word 'stairs?' occurs 1 times.
# The word 'told'st' occurs 1 times.
# The word 'short.' occurs 1 times.
# The word 'mast-head--keep' occurs 1 times.
# The word 'cloven' occurs 1 times.
# The word 'shallop's' occurs 1 times.
# The word 'mate,--who' occurs 1 times.
# The word 'tackle-ropes' occurs 1 times.
# The word 'deck--and' occurs 1 times.
# The word 'so."' occurs 1 times.
# The word 'missing,' occurs 1 times.
# The word 'Starbuck!"' occurs 1 times.
# The word '"Truth,' occurs 1 times.
# The word 'sir:' occurs 1 times.
# The word 'truth."' occurs 1 times.
# The word 'tide;' occurs 1 times.
# The word 'flood;--and' occurs 1 times.
# The word 'crested' occurs 1 times.
# The word 'comb,' occurs 1 times.
# The word 'old;--shake' occurs 1 times.
# The word 'fastened;' occurs 1 times.
# The word 'glue.' occurs 1 times.
# The word 'captain!--noble' occurs 1 times.
# The word 'heart--go' occurs 1 times.
# The word 'not--go' occurs 1 times.
# The word 'not!--see,' occurs 1 times.
# The word 'weeps;' occurs 1 times.
# The word 'persuasion' occurs 1 times.
# The word 'then!"' occurs 1 times.
# The word 'away!"--cried' occurs 1 times.
# The word 'crew!"' occurs 1 times.
# The word 'sharks!"' occurs 1 times.
# The word 'cabin-window' occurs 1 times.
# The word '"O' occurs 1 times.
# The word 'high-lifted' occurs 2 times.
# The word 'maliciously' occurs 1 times.
# The word 'bites.' occurs 1 times.
# The word 'prescient' occurs 1 times.
# The word 'hover' occurs 1 times.
# The word 'regiments' occurs 1 times.
# The word 'senses' occurs 1 times.
# The word 'sharks--a' occurs 1 times.
# The word 'them,--however' occurs 1 times.
# The word 'molesting' occurs 1 times.
# The word '"Heart' occurs 1 times.
# The word 'steel!"' occurs 1 times.
# The word 'boat--"canst' occurs 1 times.
# The word 'sight?--lowering' occurs 1 times.
# The word 'ravening' occurs 1 times.
# The word 'open-mouthed' occurs 1 times.
# The word 'day?--For' occurs 1 times.
# The word 'thing--be' occurs 1 times.
# The word 'may.' occurs 1 times.
# The word 'expectant,--fixed' occurs 1 times.
# The word 'shudder!' occurs 1 times.
# The word 'Future' occurs 1 times.
# The word 'skeletons;' occurs 1 times.
# The word 'dim.' occurs 1 times.
# The word 'girl!' occurs 1 times.
# The word 'fadest' occurs 1 times.
# The word 'Strangest' occurs 1 times.
# The word 'clearing;' occurs 1 times.
# The word 'between--Is' occurs 1 times.
# The word 'journey's' occurs 1 times.
# The word 'faint;' occurs 1 times.
# The word 'Feel' occurs 1 times.
# The word 'heart,--beats' occurs 1 times.
# The word 'yet?' occurs 1 times.
# The word 'Stir' occurs 1 times.
# The word 'Starbuck!--stave' occurs 1 times.
# The word 'off--move,' occurs 1 times.
# The word 'move!' occurs 1 times.
# The word 'aloud!--Mast-head' occurs 1 times.
# The word 'hill?--Crazed;--aloft' occurs 1 times.
# The word 'there!--keep' occurs 1 times.
# The word 'boats:--' occurs 1 times.
# The word 'whale!--Ho!' occurs 1 times.
# The word 'again!--drive' occurs 1 times.
# The word 'hawk!' occurs 1 times.
# The word 'pecks--he' occurs 1 times.
# The word 'vane"--pointing' occurs 1 times.
# The word 'main-truck--"Ha!' occurs 1 times.
# The word 'soars' occurs 1 times.
# The word 'it!--Where's' occurs 1 times.
# The word 'Ahab!--shudder,' occurs 1 times.
# The word 'shudder!"' occurs 1 times.
# The word 'mast-heads--a' occurs 1 times.
# The word 'sounded;' occurs 1 times.
# The word 'intending' occurs 1 times.
# The word 'head-beat' occurs 1 times.
# The word '"Drive,' occurs 1 times.
# The word 'nails,' occurs 2 times.
# The word 'waves!' occurs 1 times.
# The word 'mine:--and' occurs 1 times.
# The word 'circles;' occurs 1 times.
# The word 'upheaved,' occurs 1 times.
# The word 'berg' occurs 1 times.
# The word 'bedraggled' occurs 1 times.
# The word 'ropes,' occurs 1 times.
# The word 'lengthwise,' occurs 1 times.
# The word 'Shrouded' occurs 1 times.
# The word 'swamping' occurs 1 times.
# The word 'Crushed' occurs 1 times.
# The word 'brokenly' occurs 1 times.
# The word 'flakes,' occurs 1 times.
# The word 'creamed' occurs 1 times.
# The word 'attack;' occurs 1 times.
# The word 'yesterday's' occurs 1 times.
# The word 'combinedly' occurs 1 times.
# The word 'tiers' occurs 1 times.
# The word 'overspreading' occurs 2 times.
# The word 'knitted' occurs 1 times.
# The word 'flailed' occurs 1 times.
# The word 'mates'' occurs 1 times.
# The word 'scar.' occurs 1 times.
# The word 'Lashed' occurs 1 times.
# The word 'frayed' occurs 1 times.
# The word 'shreds;' occurs 1 times.
# The word '"Befooled,' occurs 1 times.
# The word 'befooled!"--drawing' occurs 1 times.
# The word 'breath--"Aye,' occurs 1 times.
# The word 'Parsee!' occurs 1 times.
# The word 'again.--Aye,' occurs 1 times.
# The word 'goest' occurs 1 times.
# The word 'promise.' occurs 1 times.
# The word 'hearse?' occurs 1 times.
# The word 'repair' occurs 1 times.
# The word 'die--Down,' occurs 1 times.
# The word 'me.--Where's' occurs 1 times.
# The word 'bore,' occurs 1 times.
# The word 'ship,--which' occurs 1 times.
# The word 'headway' occurs 1 times.
# The word 'desist.' occurs 1 times.
# The word 'seekest' occurs 1 times.
# The word 'canvas.' occurs 1 times.
# The word 'judicious' occurs 1 times.
# The word 'interval.' occurs 1 times.
# The word 'staved' occurs 1 times.
# The word 'repairing' occurs 1 times.
# The word 'port-holes,' occurs 1 times.
# The word 'busying' occurs 1 times.
# The word 'rallied.' occurs 1 times.
# The word 'vane' occurs 1 times.
# The word 'main-mast-head,' occurs 1 times.
# The word 'bore;' occurs 1 times.
# The word 'abate,' occurs 1 times.
# The word 'pertinaciously' occurs 1 times.
# The word 'crunched,' occurs 1 times.
# The word 'splinters' occurs 1 times.
# The word 'dip.' occurs 1 times.
# The word '"Heed' occurs 1 times.
# The word 'not!' occurs 1 times.
# The word 'rowlocks' occurs 1 times.
# The word 'Pull' occurs 1 times.
# The word 'bite,' occurs 1 times.
# The word 'smaller!"' occurs 1 times.
# The word 'on!--But' occurs 1 times.
# The word 'tell"--he' occurs 1 times.
# The word 'muttered--"whether' occurs 1 times.
# The word 'Ahab?--But' occurs 1 times.
# The word 'now--we' occurs 1 times.
# The word 'pass,"--and' occurs 1 times.
# The word 'advance--as' occurs 1 times.
# The word 'will--and' occurs 1 times.
# The word 'Monadnock' occurs 1 times.
# The word 'poise,' occurs 1 times.
# The word 'fiercer' occurs 1 times.
# The word 'morass,' occurs 1 times.
# The word 'writhed;' occurs 1 times.
# The word 'clung,' occurs 1 times.
# The word 'oarsmen--who' occurs 1 times.
# The word 'foreknew' occurs 1 times.
# The word 'unprepared' occurs 1 times.
# The word 'effects--these' occurs 1 times.
# The word 'fell,' occurs 1 times.
# The word 'inboard' occurs 1 times.
# The word 'simultaneously,' occurs 1 times.
# The word 'ungraduated,' occurs 1 times.
# The word 'seats,' occurs 1 times.
# The word 'tug,' occurs 1 times.
# The word 'sinew' occurs 1 times.
# The word 'cracks!--'tis' occurs 1 times.
# The word 'oars!' occurs 3 times.
# The word 'Burst' occurs 1 times.
# The word 'sea-crashing' occurs 1 times.
# The word 'bay;' occurs 1 times.
# The word 'evolution,' occurs 1 times.
# The word 'persecutions;' occurs 1 times.
# The word 'it--it' occurs 1 times.
# The word 'be--a' occurs 1 times.
# The word 'foe;' occurs 1 times.
# The word 'staggered;' occurs 1 times.
# The word 'hands!' occurs 1 times.
# The word 'night?"' occurs 1 times.
# The word 'ship!"' occurs 1 times.
# The word 'Slope' occurs 1 times.
# The word 'mark!' occurs 1 times.
# The word 'see:' occurs 1 times.
# The word 'sledge-hammering' occurs 1 times.
# The word 'whale-smitten' occurs 1 times.
# The word 'bow-ends' occurs 1 times.
# The word 'half-wading,' occurs 1 times.
# The word 'splashing' occurs 1 times.
# The word 'gap' occurs 1 times.
# The word 'half-wrapping' occurs 1 times.
# The word 'plaid,' occurs 1 times.
# The word 'forward-flowing' occurs 1 times.
# The word 'down-coming' occurs 1 times.
# The word 'close!' occurs 1 times.
# The word 'say--ye' occurs 1 times.
# The word 'jaw!' occurs 2 times.
# The word 'prayers?' occurs 1 times.
# The word 'fidelities?' occurs 1 times.
# The word 'lo,' occurs 1 times.
# The word 'Steady!' occurs 1 times.
# The word 'unappeasable' occurs 1 times.
# The word 'unwinking' occurs 1 times.
# The word 'eye?' occurs 1 times.
# The word 'mattrass' occurs 1 times.
# The word 'soft;' occurs 1 times.
# The word 'brushwood!' occurs 1 times.
# The word 'assassins' occurs 1 times.
# The word 'ghost.' occurs 1 times.
# The word 'gulping' occurs 1 times.
# The word 'drawers!' occurs 1 times.
# The word 'though;--cherries!' occurs 1 times.
# The word 'cherries!' occurs 2 times.
# The word 'die!"' occurs 1 times.
# The word '"Cherries?' occurs 1 times.
# The word 'grow.' occurs 1 times.
# The word 'part-pay' occurs 1 times.
# The word 'coppers' occurs 1 times.
# The word 'up."' occurs 1 times.
# The word 'inactive;' occurs 1 times.
# The word 'employments;' occurs 1 times.
# The word 'predestinating' occurs 1 times.
# The word 'rushed.' occurs 1 times.
# The word 'Retribution,' occurs 1 times.
# The word 'buttress' occurs 1 times.
# The word 'reeled.' occurs 1 times.
# The word 'dislodged' occurs 1 times.
# The word 'trucks,' occurs 1 times.
# The word 'bull-like' occurs 1 times.
# The word 'necks.' occurs 1 times.
# The word 'breach,' occurs 1 times.
# The word 'pour,' occurs 1 times.
# The word 'torrents' occurs 1 times.
# The word 'flume.' occurs 1 times.
# The word 'hearse!--the' occurs 1 times.
# The word 'hearse!"' occurs 1 times.
# The word '"its' occurs 1 times.
# The word 'American!"' occurs 1 times.
# The word 'Diving' occurs 1 times.
# The word 'quiescent.' occurs 1 times.
# The word 'Tashtego!' occurs 1 times.
# The word 'unsurrendered' occurs 1 times.
# The word 'uncracked' occurs 1 times.
# The word 'god-bullied' occurs 1 times.
# The word 'Pole-pointed' occurs 1 times.
# The word 'prow,--death-glorious' occurs 1 times.
# The word 'perish,' occurs 1 times.
# The word 'Am' occurs 1 times.
# The word 'captains?' occurs 1 times.
# The word 'bounds,' occurs 1 times.
# The word 'foregone' occurs 1 times.
# The word 'comber' occurs 1 times.
# The word 'all-destroying' occurs 1 times.
# The word 'unconquering' occurs 1 times.
# The word 'grapple' occurs 1 times.
# The word 'stab' occurs 1 times.
# The word 'hate's' occurs 1 times.
# The word 'Sink' occurs 1 times.
# The word 'pool!' occurs 1 times.
# The word 'THUS,' occurs 1 times.
# The word 'grooves;--ran' occurs 1 times.
# The word 'foul.' occurs 1 times.
# The word 'voicelessly' occurs 1 times.
# The word 'mutes' occurs 1 times.
# The word 'bowstring' occurs 1 times.
# The word 'victim,' occurs 1 times.
# The word 'stark-empty' occurs 1 times.
# The word 'depths.' occurs 1 times.
# The word 'bewildering' occurs 1 times.
# The word 'mediums' occurs 1 times.
# The word 'gaseous' occurs 1 times.
# The word 'Fata' occurs 1 times.
# The word 'Morgana;' occurs 1 times.
# The word 'infatuation,' occurs 1 times.
# The word 'fidelity,' occurs 1 times.
# The word 'fate,' occurs 1 times.
# The word 'perches,' occurs 1 times.
# The word 'lookouts' occurs 1 times.
# The word 'lance-pole,' occurs 1 times.
# The word 'spinning,' occurs 1 times.
# The word 'animate' occurs 1 times.
# The word 'inanimate,' occurs 1 times.
# The word 'vortex,' occurs 1 times.
# The word 'whelmings' occurs 1 times.
# The word 'intermixingly' occurs 1 times.
# The word 'undulated,' occurs 1 times.
# The word 'ironical' occurs 1 times.
# The word 'coincidings,' occurs 1 times.
# The word 'destroying' occurs 1 times.
# The word 'touched;--at' occurs 1 times.
# The word 'backwardly' occurs 1 times.
# The word 'sky-hawk' occurs 1 times.
# The word 'tauntingly' occurs 1 times.
# The word 'incommoding' occurs 1 times.
# The word 'intercept' occurs 1 times.
# The word 'etherial' occurs 1 times.
# The word 'thrill,' occurs 1 times.
# The word 'death-gasp,' occurs 1 times.
# The word 'shrieks,' occurs 1 times.
# The word 'Satan,' occurs 1 times.
# The word 'gulf;' occurs 1 times.
# The word 'Epilogue' occurs 1 times.
# The word '"AND' occurs 1 times.
# The word 'ONLY' occurs 1 times.
# The word 'AM' occurs 1 times.
# The word 'ESCAPED' occurs 1 times.
# The word 'ALONE' occurs 1 times.
# The word 'THEE"' occurs 1 times.
# The word 'Job.' occurs 1 times.
# The word 'drama's' occurs 1 times.
# The word 'forth?--Because' occurs 1 times.
# The word 'chanced,' occurs 1 times.
# The word 'Fates' occurs 1 times.
# The word 'post;' occurs 1 times.
# The word 'halfspent' occurs 1 times.
# The word 'suction' occurs 1 times.
# The word 'closing' occurs 1 times.
# The word 'vortex.' occurs 1 times.
# The word 'pool.' occurs 1 times.
# The word 'button-like' occurs 1 times.
# The word 'Ixion' occurs 1 times.
# The word 'Till,' occurs 1 times.
# The word 'burst;' occurs 1 times.
# The word 'liberated' occurs 1 times.
# The word 'Buoyed' occurs 1 times.
# The word 'dirgelike' occurs 1 times.
# The word 'padlocks' occurs 1 times.
# The word 'sheathed' occurs 1 times.
# The word 'beaks.' occurs 1 times.
# The word 'devious-cruising' occurs 1 times.
# The word 'retracing' occurs 1 times.
# The word 'orphan.' occurs 1 times.
